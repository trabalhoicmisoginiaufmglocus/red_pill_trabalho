# %%
import pandas as pd

from google.colab import drive
drive.mount('/content/drive')
folder_path = '/content/drive/MyDrive/red_pill_analises/data_base/resultados/Bertopic_Carlos_Final/DadosVideos/'

arq1 = 'topic_descriptions_final.csv'
df1 = pd.read_csv(folder_path + arq1, sep=';')
# Out:
# Mounted at /content/drive

# %%
from IPython.display import display
display(df1)
# Out:
#     Topic  Count                                               Name  \
# 0      -1    943                            -1_abre_ai_us_instagram
# 1       0   3362                        0_vamos_video_perder_nenhum
# 2       1   2318                          1_marido_esposa_cara_anos
# 3       2   1844                      2_flags_entrada_começo_lições
# 4       3    928                       3_reflexão_shorts_posso_devo
# 5       4    615  4_método_seducao_homemdealtovalor_desenvolvime...
# 6       5    588  5_namorosafado_redpilled_machomacho_conquistar...
# 7       6    557                    6_redcast_masters_meses_hotmart
# 8       7    498     7_contribuição_informado_interessam_atualidade
# 9       8    498    8_homemmoderno_homemdevalor_motivação_motivacao
# 10      9    446       9_projetoconselho_conselho_twitter_microfone
# 11     10    423        10_antiotario_redpill_opinião_redpillbrasil
# 12     11    408              11_feminista_sistema_feminismo_filhos
# 13     12    402       12_masculinidade_respeito_muitas_comunicação
# 14     13    385                 13_livro_antiotário_domine_vendido
# 15     14    347            14_hashtags_curso_relacionamentos_neste
# 16     15    330                15_musculação_raiam_academia_shorts
# 17     16    306                        16_voce_aula_apaixonar_kwai
# 18     17    294  17_antiotariopro_oferta_antiotarioprooficial_f...
# 19     18    238              18_sigma_humildade_principios_evoluir
# 20     19    232   19_homemmoderno_homemdevalor_motivacao_motivação
# 21     20    223             20_casamentonapraia_casal_namoro_macho
# 22     21    219                      21_quiser_aumentando_vsm_novo
# 23     22    196                      22_coisas_atitudes_kwai_dicas
#
#                                        Representation  \
# 0   ['abre', 'ai', 'us', 'instagram', 'capital', '...
# 1   ['vamos', 'video', 'perder', 'nenhum', 'além',...
# 2   ['marido', 'esposa', 'cara', 'anos', 'filho', ...
# 3   ['flags', 'entrada', 'começo', 'lições', 'apen...
# 4   ['reflexão', 'shorts', 'posso', 'devo', 'namor...
# 5   ['método', 'seducao', 'homemdealtovalor', 'des...
# 6   ['namorosafado', 'redpilled', 'machomacho', 'c...
# 7   ['redcast', 'masters', 'meses', 'hotmart', 'in...
# 8   ['contribuição', 'informado', 'interessam', 'a...
# 9   ['homemmoderno', 'homemdevalor', 'motivação', ...
# 10  ['projetoconselho', 'conselho', 'twitter', 'mi...
# 11  ['antiotario', 'redpill', 'opinião', 'redpillb...
# 12  ['feminista', 'sistema', 'feminismo', 'filhos'...
# 13  ['masculinidade', 'respeito', 'muitas', 'comun...
# 14  ['livro', 'antiotário', 'domine', 'vendido', '...
# 15  ['hashtags', 'curso', 'relacionamentos', 'nest...
# 16  ['musculação', 'raiam', 'academia', 'shorts', ...
# 17  ['voce', 'aula', 'apaixonar', 'kwai', 'guia', ...
# 18  ['antiotariopro', 'oferta', 'antiotarioproofic...
# 19  ['sigma', 'humildade', 'principios', 'evoluir'...
# 20  ['homemmoderno', 'homemdevalor', 'motivacao', ...
# 21  ['casamentonapraia', 'casal', 'namoro', 'macho...
# 22  ['quiser', 'aumentando', 'vsm', 'novo', 'insta...
# 23  ['coisas', 'atitudes', 'kwai', 'dicas', 'louco...
#
#                                   Representative_Docs
# 0   ['ELA VAI DESTRUIR SUA VIDA POR COMPLETO [se t...
# 1   ['OS HOMENS NÃO QUEREM MAIS FICAR FAZENDO A VO...
# 2   ['Quando o cara dá o Signal 🙅🏻 ', 'Marido quer...
# 3   ['Como você quer viver sua vida? 📕 - AntiOtári...
# 4   ['Como ser um homem de valor? | Thiago Schutz ...
# 5   ['#seducao #podcast #homemdealtovalor #comport...
# 6   ['MULHER DE VALOR #relacionamento #namoro #cas...
# 7   ['DEBATE (A REVANCHE): MANGINA X REDPILL (JÚNI...
# 8   ['Seja Babaca #hackeandoamatrix ⭐Seja membro p...
# 9   ['Homem jogava só um tijolo #homem #homens #ho...
# 10  ['Homens não estão mais CHEGANDO nas MULHERES ...
# 11  ['Quando uma mulher estiver desinteressa por v...
# 12  ['A INCRÍVEL GERAÇÃO DE MULHERES FRACAS! SEM P...
# 13  ['A Lei Maria da Penha Precisa Mudar: Falsas A...
# 14  ['Não seja inimiga do seu parceiro 1- Adquira ...
# 15  ['Reflexão Final  Como se Proteger e Evoluir n...
# 16  ['A Pista Tá Salgada: TREZOITÃO MANDA a REAL s...
# 17  ['COMO APRENDER A SER AMADA E VALORIZADA POR U...
# 18  ['Qual a sua opinião? 🤔 📕- ANTIOTÁRIO: https:/...
# 19  ['👍 #Redpill #sigma #evolução #homem #homemdev...
# 20  ['a mulher muda muito #homem #homens #motivaca...
# 21  ['ISSO É CASAMENTO #relacionamento #namoro #ca...
# 22  ['NÃO ESPERE AMOR DE UMA MULHER Clique no link...
# 23  ['O QUE O HOMEM NÃO GOSTA NA MULHER #amor #rel...

# %%
top_25_canais = df1[1:15] #montando um novo dataframe com apenas as 25 primeiras linhas MENOS a linha zero
#cal. da porcentagem entre os 25 primeiros em relação. ao total:
total_top_25 = top_25_canais['Count'].sum()
total_geral = df1['Count'].sum()
porcentagem_top_25 = (total_top_25 / total_geral) * 100
print(f'{porcentagem_top_25:.2f}% do total.')
# Out:
# 79.95% do total.

# %%
display(top_25_canais.drop(columns=['Representative_Docs']))
# Out:
#     Topic  Count                                               Name  \
# 1       0   3362                        0_vamos_video_perder_nenhum
# 2       1   2318                          1_marido_esposa_cara_anos
# 3       2   1844                      2_flags_entrada_começo_lições
# 4       3    928                       3_reflexão_shorts_posso_devo
# 5       4    615  4_método_seducao_homemdealtovalor_desenvolvime...
# 6       5    588  5_namorosafado_redpilled_machomacho_conquistar...
# 7       6    557                    6_redcast_masters_meses_hotmart
# 8       7    498     7_contribuição_informado_interessam_atualidade
# 9       8    498    8_homemmoderno_homemdevalor_motivação_motivacao
# 10      9    446       9_projetoconselho_conselho_twitter_microfone
# 11     10    423        10_antiotario_redpill_opinião_redpillbrasil
# 12     11    408              11_feminista_sistema_feminismo_filhos
# 13     12    402       12_masculinidade_respeito_muitas_comunicação
# 14     13    385                 13_livro_antiotário_domine_vendido
#
#                                        Representation
# 1   ['vamos', 'video', 'perder', 'nenhum', 'além',...
# 2   ['marido', 'esposa', 'cara', 'anos', 'filho', ...
# 3   ['flags', 'entrada', 'começo', 'lições', 'apen...
# 4   ['reflexão', 'shorts', 'posso', 'devo', 'namor...
# 5   ['método', 'seducao', 'homemdealtovalor', 'des...
# 6   ['namorosafado', 'redpilled', 'machomacho', 'c...
# 7   ['redcast', 'masters', 'meses', 'hotmart', 'in...
# 8   ['contribuição', 'informado', 'interessam', 'a...
# 9   ['homemmoderno', 'homemdevalor', 'motivação', ...
# 10  ['projetoconselho', 'conselho', 'twitter', 'mi...
# 11  ['antiotario', 'redpill', 'opinião', 'redpillb...
# 12  ['feminista', 'sistema', 'feminismo', 'filhos'...
# 13  ['masculinidade', 'respeito', 'muitas', 'comun...
# 14  ['livro', 'antiotário', 'domine', 'vendido', '...
